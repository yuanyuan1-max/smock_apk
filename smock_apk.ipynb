# %%
import cv2
import pygame
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk

# 加载模型
model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
model = YOLO(model_path)  # 加载自定义模型权重

class FireDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Fire Detection")
        self.root.geometry("800x600")

        # 添加按钮
        self.start_cam_btn = tk.Button(root, text="开启摄像头", command=self.start_camera)
        self.start_cam_btn.pack()

        self.upload_image_btn = tk.Button(root, text="上传图片", command=self.upload_image)
        self.upload_image_btn.pack()

        self.upload_video_btn = tk.Button(root, text="上传视频", command=self.upload_video)
        self.upload_video_btn.pack()

        # 设置表格
        columns = ("file", "coordinates", "confidence")
        self.treeview = ttk.Treeview(root, columns=columns, show='headings')
        self.treeview.heading("file", text="视频\\图片信息")
        self.treeview.heading("coordinates", text="识别坐标位置")
        self.treeview.heading("confidence", text="可信度")
        self.treeview.pack(fill=tk.BOTH, expand=True)

        # 初始化Pygame
        pygame.init()
        self.screen = None
        self.running = False

    def start_camera(self):
        self.cap = cv2.VideoCapture(0)  # 0 表示默认摄像头
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Cannot open camera")
            return
        self.running = True
        self.process_camera()

    def process_camera(self):
        if self.running:
            ret, frame = self.cap.read()
            if ret:
                self.process_frame(frame)
                self.root.after(10, self.process_camera)
            else:
                messagebox.showerror("Error", "Cannot read frame")
                self.running = False

    def upload_image(self):
        file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
        if file_path:
            frame = cv2.imread(file_path)
            self.process_frame(frame, file_path)

    def upload_video(self):
        file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4;*.avi;*.mov")])
        if file_path:
            cap = cv2.VideoCapture(file_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                self.process_frame(frame, file_path)
            cap.release()

    def process_frame(self, frame, file_path=None):
        results = model(frame)
        for result in results:
            for box in result.boxes:
                coords = box.xyxy.tolist()
                if len(coords) == 1 and len(coords[0]) == 4:
                    x1, y1, x2, y2 = coords[0]
                    conf = box.conf.item()
                    cls = box.cls.item()
                    label = f'{model.names[int(cls)]} {conf:.2f}'
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
                    self.treeview.insert("", tk.END, values=(file_path or "Camera", f"({x1}, {y1}), ({x2}, {y2})", f"{conf:.2f}"))

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = pygame.surfarray.make_surface(frame.swapaxes(0, 1))
        if self.screen is None:
            self.screen = pygame.display.set_mode((frame.get_width(), frame.get_height()))
        self.screen.blit(frame, (0, 0))
        pygame.display.flip()

    def on_close(self):
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        pygame.quit()
        self.root.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = FireDetectionApp(root)
    root.protocol("WM_DELETE_WINDOW", app.on_close)
    root.mainloop()

# %%
import cv2
import pygame
import os
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk

# 加载模型
model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
model = YOLO(model_path)  # 加载自定义模型权重

class FireDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Fire Detection")
        self.root.geometry("1200x800")  # 设置窗口大小

        # 设置布局
        self.frame_buttons = tk.Frame(root)
        self.frame_buttons.pack(side=tk.TOP, fill=tk.X)
        
        self.frame_video = tk.Frame(root)
        self.frame_video.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        self.frame_results = tk.Frame(root)
        self.frame_results.pack(side=tk.RIGHT, fill=tk.Y)

        # 添加按钮
        self.start_cam_btn = tk.Button(self.frame_buttons, text="开启摄像头", command=self.start_camera)
        self.start_cam_btn.pack(side=tk.LEFT)

        self.upload_image_btn = tk.Button(self.frame_buttons, text="上传图片", command=self.upload_image)
        self.upload_image_btn.pack(side=tk.LEFT)

        self.upload_video_btn = tk.Button(self.frame_buttons, text="上传视频", command=self.upload_video)
        self.upload_video_btn.pack(side=tk.LEFT)

        # 设置表格
        columns = ("file", "coordinates", "confidence")
        self.treeview = ttk.Treeview(self.frame_results, columns=columns, show='headings')
        self.treeview.heading("file", text="视频\\图片信息")
        self.treeview.heading("coordinates", text="识别坐标位置")
        self.treeview.heading("confidence", text="可信度")
        self.treeview.pack(fill=tk.BOTH, expand=True)

        # 初始化Pygame
        pygame.init()
        self.screen = None
        self.running = False

    def start_camera(self):
        """启动摄像头并开始处理视频流"""
        self.cap = cv2.VideoCapture(0)  # 0 表示默认摄像头
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Cannot open camera")
            return
        self.running = True
        self.process_camera()

    def process_camera(self):
        """处理摄像头视频流"""
        if self.running:
            ret, frame = self.cap.read()
            if ret:
                self.process_frame(frame)
                self.root.after(10, self.process_camera)  # 每10毫秒处理一帧
            else:
                messagebox.showerror("Error", "Cannot read frame")
                self.running = False

    def upload_image(self):
        """上传并处理图片"""
        file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
        if file_path:
            frame = cv2.imread(file_path)
            self.process_frame(frame, file_path)

    def upload_video(self):
        """上传并处理视频"""
        file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4;*.avi;*.mov")])
        if file_path:
            cap = cv2.VideoCapture(file_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                self.process_frame(frame, file_path)
            cap.release()

    def process_frame(self, frame, file_path=None):
        """处理视频帧并进行目标检测"""
        results = model(frame)
        for result in results:
            for box in result.boxes:
                coords = box.xyxy.tolist()
                if len(coords) == 1 and len(coords[0]) == 4:
                    x1, y1, x2, y2 = coords[0]
                    conf = box.conf.item()
                    cls = box.cls.item()
                    label = f'{model.names[int(cls)]} {conf:.2f}'
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
                    self.treeview.insert("", tk.END, values=(file_path or "Camera", f"({x1}, {y1}), ({x2}, {y2})", f"{conf:.2f}"))

        # 将帧从BGR转换为RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 将帧转换为Pygame图像
        frame = pygame.surfarray.make_surface(frame.swapaxes(0, 1))

        # 如果尚未创建Pygame窗口，则创建窗口
        if self.screen is None:
            os.environ['SDL_WINDOWID'] = str(self.frame_video.winfo_id())
            os.environ['SDL_VIDEODRIVER'] = 'windib'
            self.screen = pygame.display.set_mode((frame.get_width(), frame.get_height()))

        # 显示帧
        self.screen.blit(frame, (0, 0))
        pygame.display.flip()

    def on_close(self):
        """关闭窗口时执行的操作"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        pygame.quit()
        self.root.destroy()
    
if __name__ == "__main__":
    root = tk.Tk()
    app = FireDetectionApp(root)
    root.protocol("WM_DELETE_WINDOW", app.on_close)
    root.mainloop()

# %%
import cv2
import pygame
import os
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk

# 加载模型
model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
model = YOLO(model_path)  # 加载自定义模型权重

class FireDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("吸烟识别系统V2.0 by Miss小远")
        self.root.geometry("1200x800")  # 设置窗口大小

        # # #设置背景
        # self.background_image = Image.open("./background.jpg")
        # self.background_photo = ImageTk.PhotoImage(self.background_image)
        
        # 设置标题
        self.title_label = tk.Label(root, text="吸烟识别系统V2.0 by Miss小远", font=("Helvetica", 16))
        self.title_label.pack(side=tk.TOP, pady=10)

        # 设置布局
        self.frame_buttons = tk.Frame(root)
        self.frame_buttons.pack(side=tk.TOP, fill=tk.X)

        self.frame_video = tk.Frame(root)
        self.frame_video.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        self.frame_results = tk.Frame(root)
        self.frame_results.pack(side=tk.RIGHT, fill=tk.Y)

        # 添加按钮
        self.start_cam_btn = tk.Button(self.frame_buttons, text="开启摄像头", command=self.start_camera)
        self.start_cam_btn.pack(side=tk.LEFT)

        self.upload_image_btn = tk.Button(self.frame_buttons, text="上传图片", command=self.upload_image)
        self.upload_image_btn.pack(side=tk.LEFT)

        self.upload_video_btn = tk.Button(self.frame_buttons, text="上传视频", command=self.upload_video)
        self.upload_video_btn.pack(side=tk.LEFT)

        # 添加摄像头选择下拉菜单
        self.camera_var = tk.StringVar(value="选择摄像头")
        self.camera_menu = tk.OptionMenu(self.frame_buttons, self.camera_var, "选择摄像头")
        self.camera_menu.pack(side=tk.LEFT)

        # 设置表格
        columns = ("file", "coordinates", "confidence")
        self.treeview = ttk.Treeview(self.frame_results, columns=columns, show='headings')
        self.treeview.heading("file", text="视频\\图片信息")
        self.treeview.heading("coordinates", text="识别坐标位置")
        self.treeview.heading("confidence", text="可信度")
        self.treeview.pack(fill=tk.BOTH, expand=True)

        # 初始化Pygame
        pygame.init()
        self.screen = None
        self.running = False

        # 初始化摄像头列表
        self.camera_list = self.get_camera_list()
        if self.camera_list:
            self.camera_var.set(self.camera_list[0])
            self.camera_menu['menu'].delete(0, 'end')
            for camera in self.camera_list:
                self.camera_menu['menu'].add_command(label=camera, command=tk._setit(self.camera_var, camera))

    def get_camera_list(self):
        """获取可用摄像头列表"""
        camera_list = []
        for i in range(4):
            cap = cv2.VideoCapture(i)
            if cap.isOpened():
                camera_list.append(f"Camera {i}")
                cap.release()
        return camera_list

    def start_camera(self):
        """启动摄像头并开始处理视频流"""
        camera_index = int(self.camera_var.get().split()[1])
        self.cap = cv2.VideoCapture(camera_index)  # 选择的摄像头
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Cannot open camera")
            return
        self.running = True
        self.process_camera()

    def process_camera(self):
        """处理摄像头视频流"""
        if self.running:
            ret, frame = self.cap.read()
            if ret:
                self.process_frame(frame)
                self.root.after(10, self.process_camera)  # 每10毫秒处理一帧
            else:
                messagebox.showerror("Error", "Cannot read frame")
                self.running = False

    def upload_image(self):
        """上传并处理图片"""
        file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
        if file_path:
            frame = cv2.imread(file_path)
            self.process_frame(frame, file_path)

    def upload_video(self):
        """上传并处理视频"""
        file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4;*.avi;*.mov")])
        if file_path:
            cap = cv2.VideoCapture(file_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                self.process_frame(frame, file_path)
            cap.release()

    def process_frame(self, frame, file_path=None):
        """处理视频帧并进行目标检测"""
        results = model(frame)
        for result in results:
            for box in result.boxes:
                coords = box.xyxy.tolist()
                if len(coords) == 1 and len(coords[0]) == 4:
                    x1, y1, x2, y2 = coords[0]
                    conf = box.conf.item()
                    cls = box.cls.item()
                    label = f'{model.names[int(cls)]} {conf:.2f}'
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
                    self.treeview.insert("", tk.END, values=(file_path or "Camera", f"({x1}, {y1}), ({x2}, {y2})", f"{conf:.2f}"))

        # 将帧从BGR转换为RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 将帧转换为Pygame图像
        frame = pygame.surfarray.make_surface(frame.swapaxes(0, 1))

        # 如果尚未创建Pygame窗口，则创建窗口
        if self.screen is None:
            os.environ['SDL_WINDOWID'] = str(self.frame_video.winfo_id())
            os.environ['SDL_VIDEODRIVER'] = 'windib'
            self.screen = pygame.display.set_mode((frame.get_width(), frame.get_height()))

        # 显示帧
        self.screen.blit(frame, (0, 0))
        pygame.display.flip()

    def on_close(self):
        """关闭窗口时执行的操作"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        pygame.quit()
        self.root.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = FireDetectionApp(root)
    root.protocol("WM_DELETE_WINDOW", app.on_close)
    root.mainloop()

# %%
import cv2
import pygame
import os
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk

# 加载模型
model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
model = YOLO(model_path)  # 加载自定义模型权重

class FireDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("吸烟识别系统V2.0 by Miss小远")
        self.root.geometry("1200x800")  # 设置窗口大小

        # 设置标题
        self.title_label = tk.Label(root, text="吸烟识别系统V2.0 by Miss小远", font=("Helvetica", 16))
        self.title_label.pack(side=tk.TOP, pady=10)

        # 设置布局
        self.frame_buttons = tk.Frame(root)
        self.frame_buttons.pack(side=tk.TOP, fill=tk.X)

        self.frame_video = tk.Frame(root)
        self.frame_video.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        self.frame_results = tk.Frame(root)
        self.frame_results.pack(side=tk.RIGHT, fill=tk.Y)

        # 添加按钮
        self.start_cam_btn = tk.Button(self.frame_buttons, text="开启摄像头", command=self.start_camera)
        self.start_cam_btn.pack(side=tk.LEFT)

        self.upload_image_btn = tk.Button(self.frame_buttons, text="上传图片", command=self.upload_image)
        self.upload_image_btn.pack(side=tk.LEFT)

        self.upload_video_btn = tk.Button(self.frame_buttons, text="上传视频", command=self.upload_video)
        self.upload_video_btn.pack(side=tk.LEFT)

        # 添加摄像头选择下拉菜单
        self.camera_var = tk.StringVar(value="选择摄像头")
        self.camera_menu = tk.OptionMenu(self.frame_buttons, self.camera_var, "选择摄像头")
        self.camera_menu.pack(side=tk.LEFT)

        # 设置表格
        columns = ("file", "coordinates", "confidence")
        self.treeview = ttk.Treeview(self.frame_results, columns=columns, show='headings')
        self.treeview.heading("file", text="视频\\图片信息")
        self.treeview.heading("coordinates", text="识别坐标位置")
        self.treeview.heading("confidence", text="可信度")
        self.treeview.pack(fill=tk.BOTH, expand=True)

        # 初始化Pygame
        pygame.init()
        self.screen = None
        self.running = False

        # 初始化摄像头列表
        self.camera_list = self.get_camera_list()
        if self.camera_list:
            self.camera_var.set(self.camera_list[0])
            self.camera_menu['menu'].delete(0, 'end')
            for camera in self.camera_list:
                self.camera_menu['menu'].add_command(label=camera, command=tk._setit(self.camera_var, camera))

    def get_camera_list(self):
        """获取可用摄像头列表"""
        camera_list = []
        for i in range(4):
            cap = cv2.VideoCapture(i)
            if cap.isOpened():
                camera_list.append(f"Camera {i}")
                cap.release()
        return camera_list

    def start_camera(self):
        """启动摄像头并开始处理视频流"""
        if self.running:
            self.running = False
            self.cap.release()

        camera_index = int(self.camera_var.get().split()[1])
        self.cap = cv2.VideoCapture(camera_index)  # 选择的摄像头
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Cannot open camera")
            return
        self.running = True
        self.process_camera()

    def process_camera(self):
        """处理摄像头视频流"""
        if self.running:
            ret, frame = self.cap.read()
            if ret:
                self.process_frame(frame)
                self.root.after(10, self.process_camera)  # 每10毫秒处理一帧
            else:
                messagebox.showerror("Error", "Cannot read frame")
                self.running = False

    def upload_image(self):
        """上传并处理图片"""
        file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
        if file_path:
            frame = cv2.imread(file_path)
            frame = self.resize_image(frame, self.frame_video.winfo_width(), self.frame_video.winfo_height())
            self.process_frame(frame, file_path)

    def upload_video(self):
        """上传并处理视频"""
        file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4;*.avi;*.mov")])
        if file_path:
            cap = cv2.VideoCapture(file_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                self.process_frame(frame, file_path)
            cap.release()

    def resize_image(self, frame, max_width, max_height):
        """调整图像大小以适应指定的最大宽度和高度"""
        h, w = frame.shape[:2]
        scale = min(max_width / w, max_height / h)
        return cv2.resize(frame, (int(w * scale), int(h * scale)))

    def process_frame(self, frame, file_path=None):
        """处理视频帧并进行目标检测"""
        results = model(frame)
        for result in results:
            for box in result.boxes:
                coords = box.xyxy.tolist()
                if len(coords) == 1 and len(coords[0]) == 4:
                    x1, y1, x2, y2 = coords[0]
                    conf = box.conf.item()
                    cls = box.cls.item()
                    label = f'{model.names[int(cls)]} {conf:.2f}'
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
                    self.treeview.insert("", tk.END, values=(file_path or "Camera", f"({x1}, {y1}), ({x2}, {y2})", f"{conf:.2f}"))

        # 将帧从BGR转换为RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 将帧转换为Pygame图像
        frame = pygame.surfarray.make_surface(frame.swapaxes(0, 1))

        # 如果尚未创建Pygame窗口，则创建窗口
        if self.screen is None:
            os.environ['SDL_WINDOWID'] = str(self.frame_video.winfo_id())
            os.environ['SDL_VIDEODRIVER'] = 'windib'
            self.screen = pygame.display.set_mode((self.frame_video.winfo_width(), self.frame_video.winfo_height()))

        # 显示帧
        self.screen.blit(frame, (0, 0))
        pygame.display.flip()

    def on_close(self):
        """关闭窗口时执行的操作"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        pygame.quit()
        self.root.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = FireDetectionApp(root)
    root.protocol("WM_DELETE_WINDOW", app.on_close)
    root.mainloop()

# %%
import cv2
import pygame
import os
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk
import time

# 加载模型
model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
model = YOLO(model_path)  # 加载自定义模型权重

# 初始化Pygame
pygame.init()

class FireDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("吸烟识别系统V2.0 by Miss小远")
        self.root.geometry("1200x800")  # 设置窗口大小

        # 设置标题
        self.title_label = tk.Label(root, text="吸烟识别系统V2.0 by Miss小远", font=("Helvetica", 16))
        self.title_label.pack(side=tk.TOP, pady=10)

        # 设置布局
        self.frame_buttons = tk.Frame(root)
        self.frame_buttons.pack(side=tk.TOP, fill=tk.X)

        self.frame_video = tk.Frame(root)
        self.frame_video.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        self.frame_results = tk.Frame(root)
        self.frame_results.pack(side=tk.RIGHT, fill=tk.Y)

        # 添加按钮
        self.start_cam_btn = tk.Button(self.frame_buttons, text="开启摄像头", command=self.start_camera)
        self.start_cam_btn.pack(side=tk.LEFT)

        self.stop_cam_btn = tk.Button(self.frame_buttons, text="关闭摄像头", command=self.stop_camera)
        self.stop_cam_btn.pack(side=tk.LEFT)

        self.upload_image_btn = tk.Button(self.frame_buttons, text="上传图片", command=self.upload_image)
        self.upload_image_btn.pack(side=tk.LEFT)

        self.upload_video_btn = tk.Button(self.frame_buttons, text="上传视频", command=self.upload_video)
        self.upload_video_btn.pack(side=tk.LEFT)

        # 添加摄像头选择下拉菜单
        self.camera_var = tk.StringVar(value="选择摄像头")
        self.camera_menu = tk.OptionMenu(self.frame_buttons, self.camera_var, "选择摄像头")
        self.camera_menu.pack(side=tk.LEFT)

        # 设置表格
        columns = ("file", "coordinates", "confidence")
        self.treeview = ttk.Treeview(self.frame_results, columns=columns, show='headings')
        self.treeview.heading("file", text="视频\\图片信息")
        self.treeview.heading("coordinates", text="识别坐标位置")
        self.treeview.heading("confidence", text="可信度")
        self.treeview.pack(fill=tk.BOTH, expand=True)

        self.screen = None
        self.running = False

        # 初始化摄像头列表
        self.camera_list = self.get_camera_list()
        if self.camera_list:
            self.camera_var.set(self.camera_list[0])
            self.camera_menu['menu'].delete(0, 'end')
            for camera in self.camera_list:
                self.camera_menu['menu'].add_command(label=camera, command=tk._setit(self.camera_var, camera))

    def get_camera_list(self):
        """获取可用摄像头列表"""
        camera_list = []
        for i in range(4):
            cap = cv2.VideoCapture(i)
            if cap.isOpened():
                camera_list.append(f"Camera {i}")
                cap.release()
        return camera_list

    def start_camera(self):
        """启动摄像头并开始处理视频流"""
        if self.running:
            self.running = False
            self.cap.release()

        camera_index = int(self.camera_var.get().split()[1])
        self.cap = cv2.VideoCapture(camera_index)  # 选择的摄像头
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Cannot open camera")
            return
        self.running = True
        self.process_camera()

    def stop_camera(self):
        """停止摄像头"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        self.screen.fill((0, 0, 0))  # 清空Pygame屏幕
        pygame.display.flip()

    def process_camera(self):
        """处理摄像头视频流"""
        if self.running:
            ret, frame = self.cap.read()
            if ret:
                self.process_frame(frame)
                self.root.after(10, self.process_camera)  # 每10毫秒处理一帧
            else:
                messagebox.showerror("Error", "Cannot read frame")
                self.running = False

    def upload_image(self):
        """上传并处理图片"""
        file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
        if file_path:
            frame = cv2.imread(file_path)
            frame = self.resize_image(frame, self.frame_video.winfo_width(), self.frame_video.winfo_height())
            self.process_frame(frame, file_path)

    def upload_video(self):
        """上传并处理视频"""
        file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4;*.avi;*.mov")])
        if file_path:
            cap = cv2.VideoCapture(file_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                self.process_frame(frame, file_path)
            cap.release()

    def resize_image(self, frame, max_width, max_height):
        """调整图像大小以适应指定的最大宽度和高度"""
        h, w = frame.shape[:2]
        scale = min(max_width / w, max_height / h)
        return cv2.resize(frame, (int(w * scale), int(h * scale)))

    def process_frame(self, frame, file_path=None):
        """处理视频帧并进行目标检测"""
        results = model(frame)
        smocking_conf = 0
        cigarette_conf = 0
        for result in results:
            for box in result.boxes:
                coords = box.xyxy.tolist()
                if len(coords) == 1 and len(coords[0]) == 4:
                    x1, y1, x2, y2 = coords[0]
                    conf = box.conf.item()
                    cls = box.cls.item()
                    label = f'{model.names[int(cls)]} {conf:.2f}'
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
                    self.treeview.insert("", 0, values=(file_path or "Camera", f"({x1}, {y1}), ({x2}, {y2})", f"{conf:.2f}"))

                    # 检查检测到的类别并更新相应的置信度
                    if model.names[int(cls)] == "smoking":
                        smocking_conf = max(smocking_conf, conf)
                    elif model.names[int(cls)] == "cigarette":
                        cigarette_conf = max(cigarette_conf, conf)
        
        combined_conf = max(smocking_conf, cigarette_conf)
        if combined_conf >= 0.7:
            self.play_alert_sound()

        # 将帧从BGR转换为RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 将帧转换为Pygame图像
        frame = pygame.surfarray.make_surface(frame.swapaxes(0, 1))

        # 如果尚未创建Pygame窗口，则创建窗口
        if self.screen is None:
            os.environ['SDL_WINDOWID'] = str(self.frame_video.winfo_id())
            os.environ['SDL_VIDEODRIVER'] = 'windib'
            self.screen = pygame.display.set_mode((self.frame_video.winfo_width(), self.frame_video.winfo_height()))

        # 显示帧
        self.screen.blit(frame, (0, 0))
        pygame.display.flip()

    def play_alert_sound(self):
        """播放警报声音"""
        alert_sound_path = 'smock.mp3'
        if os.path.exists(alert_sound_path):
            pygame.mixer.music.load(alert_sound_path)
            pygame.mixer.music.play()

    def on_close(self):
        """关闭窗口时执行的操作"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        pygame.quit()
        self.root.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = FireDetectionApp(root)
    root.protocol("WM_DELETE_WINDOW", app.on_close)
    root.mainloop()

# %%
#coding:utf-8
import cv2
import pygame
import os
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk
import time

# 加载模型
#model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
model_path = 'D:\\BaiduNetdiskDownload\\Yolov7-CCPD.pt'
model = YOLO(model_path)  # 加载自定义模型权

# 初始化Pygame
pygame.init()

class FireDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("吸烟识别系统V2.0 by Miss小远")
        self.root.geometry("1200x800")  # 设置窗口大小

        # 设置标题
        self.title_label = tk.Label(root, text="吸烟识别系统V2.0 by Miss小远", font=("Helvetica", 16))
        self.title_label.pack(side=tk.TOP, pady=10)

        # 设置布局
        self.frame_buttons = tk.Frame(root)
        self.frame_buttons.pack(side=tk.TOP, fill=tk.X)

        self.frame_video = tk.Frame(root)
        self.frame_video.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        self.frame_results = tk.Frame(root)
        self.frame_results.pack(side=tk.RIGHT, fill=tk.Y)

        # 添加按钮
        self.start_cam_btn = tk.Button(self.frame_buttons, text="开启摄像头", command=self.start_camera)
        self.start_cam_btn.pack(side=tk.LEFT)

        self.stop_cam_btn = tk.Button(self.frame_buttons, text="关闭摄像�??", command=self.stop_camera)
        self.stop_cam_btn.pack(side=tk.LEFT)

        self.upload_image_btn = tk.Button(self.frame_buttons, text="上传图片", command=self.upload_image)
        self.upload_image_btn.pack(side=tk.LEFT)

        self.upload_video_btn = tk.Button(self.frame_buttons, text="上传视频", command=self.upload_video)
        self.upload_video_btn.pack(side=tk.LEFT)

        # 添加摄像头选择下拉菜单
        self.camera_var = tk.StringVar(value="选择摄像�??")
        self.camera_menu = tk.OptionMenu(self.frame_buttons, self.camera_var, "选择摄像�??")
        self.camera_menu.pack(side=tk.LEFT)

        # 设置表格
        columns = ("file", "coordinates", "confidence")
        self.treeview = ttk.Treeview(self.frame_results, columns=columns, show='headings')
        self.treeview.heading("file", text="视频\\图片信息")
        self.treeview.heading("coordinates", text="识别坐标位置")
        self.treeview.heading("confidence", text="可信�??")
        self.treeview.pack(fill=tk.BOTH, expand=True)

        self.screen = None
        self.running = False

        # 初始化摄像头列表
        self.camera_list = self.get_camera_list()
        if self.camera_list:
            self.camera_var.set(self.camera_list[0])
            self.camera_menu['menu'].delete(0, 'end')
            for camera in self.camera_list:
                self.camera_menu['menu'].add_command(label=camera, command=tk._setit(self.camera_var, camera))

    def get_camera_list(self):
        """获取可用摄像头列�??"""
        camera_list = []
        for i in range(4):
            cap = cv2.VideoCapture(i)
            if cap.isOpened():
                camera_list.append(f"Camera {i}")
                cap.release()
        return camera_list

    def start_camera(self):
        """启动摄像头并开始处理视频流"""
        if self.running:
            self.running = False
            self.cap.release()

        camera_index = int(self.camera_var.get().split()[1])
        self.cap = cv2.VideoCapture(camera_index)  # 选择的摄像头
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Cannot open camera")
            return
        self.running = True
        self.process_camera()

    def stop_camera(self):
        """停止摄像�??"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        self.screen.fill((0, 0, 0))  # 清空Pygame屏幕
        pygame.display.flip()

    def process_camera(self):
        """处理摄像头视频流"""
        if self.running:
            ret, frame = self.cap.read()
            if ret:
                self.process_frame(frame)
                self.root.after(10, self.process_camera)  # �??10毫秒处理一�??
            else:
                messagebox.showerror("Error", "Cannot read frame")
                self.running = False

    def upload_image(self):
        #上传并处理图�??
        file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
        if file_path:
            frame = cv2.imread(file_path)
            frame = self.resize_image(frame, self.frame_video.winfo_width(), self.frame_video.winfo_height())
            self.process_frame(frame, file_path)

    def upload_video(self):
        #上传并处理视�??
        file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4;*.avi;*.mov")])
        if file_path:
            cap = cv2.VideoCapture(file_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                self.process_frame(frame, file_path)
            cap.release()

    def resize_image(self, frame, max_width, max_height):
        #调整图像大小以适应指定的最大宽度和高度
        h, w = frame.shape[:2]
        scale = min(max_width / w, max_height / h)
        return cv2.resize(frame, (int(w * scale), int(h * scale)))

    def process_frame(self, frame, file_path=None):
        #处理视频帧并进行目标检�??
        results = model(frame)
        smoking_conf = 0
        for result in results:
            for box in result.boxes:
                coords = box.xyxy.tolist()
                if len(coords) == 1 and len(coords[0]) == 4:
                    x1, y1, x2, y2 = coords[0]
                    conf = box.conf.item()
                    cls = box.cls.item()
                    label = f'{model.names[int(cls)]} {conf:.2f}'
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

                    # 检查检测到的类别是smocking并更新置信度
                    if model.names[int(cls)] == "smoking":
                        smoking_conf = max(smoking_conf, conf)
                        self.treeview.insert("", 0, values=(file_path or "Camera", f"({x1}, {y1}), ({x2}, {y2})", f"{conf:.2f}"))
                        if smoking_conf >= 0.7 and not pygame.mixer.music.get_busy():
                            self.play_alert_sound()
        

        # 将帧从BGR转换为RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 将帧转换为Pygame图像
        frame = pygame.surfarray.make_surface(frame.swapaxes(0, 1))

        # 如果尚未创建Pygame窗口，则创建窗口
        if self.screen is None:
            os.environ['SDL_WINDOWID'] = str(self.frame_video.winfo_id())
            os.environ['SDL_VIDEODRIVER'] = 'windib'
            self.screen = pygame.display.set_mode((self.frame_video.winfo_width(), self.frame_video.winfo_height()))

        # 显示�??
        self.screen.blit(frame, (0, 0))
        pygame.display.flip()

    def play_alert_sound(self):
        """播放警报声音"""
        alert_sound_path = 'smock.mp3'
        if os.path.exists(alert_sound_path):
            pygame.mixer.music.load(alert_sound_path)
            pygame.mixer.music.play()

    def on_close(self):
        """关闭窗口时执行的操作"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        pygame.quit()
        self.root.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = FireDetectionApp(root)
    root.protocol("WM_DELETE_WINDOW", app.on_close)
    root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:775, in torch_safe_load(weight)
#     764     with temporary_modules(
#     765         modules={
#     766             "ultralytics.yolo.utils": "ultralytics.utils",
#    (...)
#     773         },
#     774     ):
# --> 775         ckpt = torch.load(file, map_location="cpu")
#     777 except ModuleNotFoundError as e:  # e.name is missing module name
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\serialization.py:1025, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1024                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1025         return _load(opened_zipfile,
#    1026                      map_location,
#    1027                      pickle_module,
#    1028                      overall_storage=overall_storage,
#    1029                      **pickle_load_args)
#    1030 if mmap:
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\serialization.py:1446, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1445 unpickler.persistent_load = persistent_load
# -> 1446 result = unpickler.load()
#    1448 torch._utils._validate_loaded_sparse_tensors()
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\serialization.py:1439, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1438 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1439 return super().find_class(mod_name, name)
#
# ModuleNotFoundError: No module named 'models'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      13 # 加载模型
#      14 #model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
#      15 model_path = 'D:\\BaiduNetdiskDownload\\Yolov7-CCPD.pt'
# ---> 16 model = YOLO(model_path)  # 加载自定义模型权
#      18 # 初始化Pygame
#      19 pygame.init()
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:149, in Model.__init__(self, model, task, verbose)
#     147     self._new(model, task=task, verbose=verbose)
#     148 else:
# --> 149     self._load(model, task=task)
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:230, in Model._load(self, weights, task)
#     227 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     229 if Path(weights).suffix == ".pt":
# --> 230     self.model, self.ckpt = attempt_load_one_weight(weights)
#     231     self.task = self.model.args["task"]
#     232     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:849, in attempt_load_one_weight(weight, device, inplace, fuse)
#     847 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     848     """Loads a single model weights."""
# --> 849     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     850     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#     851     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File c:\Users\26270\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:779, in torch_safe_load(weight)
#     777 except ModuleNotFoundError as e:  # e.name is missing module name
#     778     if e.name == "models":
# --> 779         raise TypeError(
#     780             emojis(
#     781                 f"ERROR ❌️ {weight} appears to be an Ultralytics YOLOv5 model originally trained "
#     782                 f"with https://github.com/ultralytics/yolov5.\nThis model is NOT forwards compatible with "
#     783                 f"YOLOv8 at https://github.com/ultralytics/ultralytics."
#     784                 f"\nRecommend fixes are to train a new model using the latest 'ultralytics' package or to "
#     785                 f"run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'"
#     786             )
#     787         ) from e
#     788     LOGGER.warning(
#     789         f"WARNING ⚠️ {weight} appears to require '{e.name}', which is not in ultralytics requirements."
#     790         f"\nAutoInstall will run now for '{e.name}' but this feature will be removed in the future."
#     791         f"\nRecommend fixes are to train a new model using the latest 'ultralytics' package or to "
#     792         f"run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'"
#     793     )
#     794     check_requirements(e.name)  # install missing module
#
# TypeError: ERROR  D:\BaiduNetdiskDownload\Yolov7-CCPD.pt appears to be an Ultralytics YOLOv5 model originally trained with https://github.com/ultralytics/yolov5.
# This model is NOT forwards compatible with YOLOv8 at https://github.com/ultralytics/ultralytics.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'

# %% [markdown]
# smock_apk

# %%
import cv2
import pygame
import os
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk
import time

# %%
import cv2
import pygame
import os
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
from tkinter import ttk
from PIL import Image, ImageTk
import time

# 加载模型
model_path = 'C:\\Users\\26270\\runs\\detect\\train4\\weights\\best.pt'
model = YOLO(model_path)  # 加载自定义模型权重

# 初始化Pygame
pygame.init()

class FireDetectionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("吸烟识别系统V2.0 by Miss小远")
        self.root.geometry("1200x800")  # 设置窗口大小

        # 设置标题
        self.title_label = tk.Label(root, text="吸烟识别系统V2.0 by Miss小远", font=("Helvetica", 16))
        self.title_label.pack(side=tk.TOP, pady=10)

        # 设置布局
        self.frame_buttons = tk.Frame(root)
        self.frame_buttons.pack(side=tk.TOP, fill=tk.X)

        self.frame_video = tk.Frame(root)
        self.frame_video.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        self.frame_results = tk.Frame(root)
        self.frame_results.pack(side=tk.RIGHT, fill=tk.Y)

        # 添加按钮
        self.start_cam_btn = tk.Button(self.frame_buttons, text="开启摄像头", command=self.start_camera)
        self.start_cam_btn.pack(side=tk.LEFT)

        self.stop_cam_btn = tk.Button(self.frame_buttons, text="关闭摄像头", command=self.stop_camera)
        self.stop_cam_btn.pack(side=tk.LEFT)

        self.upload_image_btn = tk.Button(self.frame_buttons, text="上传图片", command=self.upload_image)
        self.upload_image_btn.pack(side=tk.LEFT)

        self.upload_video_btn = tk.Button(self.frame_buttons, text="上传视频", command=self.upload_video)
        self.upload_video_btn.pack(side=tk.LEFT)

        # 添加摄像头选择下拉菜单
        self.camera_var = tk.StringVar(value="选择摄像头")
        self.camera_menu = tk.OptionMenu(self.frame_buttons, self.camera_var, "选择摄像头")
        self.camera_menu.pack(side=tk.LEFT)

        # 设置表格
        columns = ("file", "coordinates", "confidence")
        self.treeview = ttk.Treeview(self.frame_results, columns=columns, show='headings')
        self.treeview.heading("file", text="视频\\图片信息")
        self.treeview.heading("coordinates", text="识别坐标位置")
        self.treeview.heading("confidence", text="可信度")
        self.treeview.pack(fill=tk.BOTH, expand=True)

        self.screen = None
        self.running = False

        # 初始化摄像头列表
        self.camera_list = self.get_camera_list()
        if self.camera_list:
            self.camera_var.set(self.camera_list[0])
            self.camera_menu['menu'].delete(0, 'end')
            for camera in self.camera_list:
                self.camera_menu['menu'].add_command(label=camera, command=tk._setit(self.camera_var, camera))

    def get_camera_list(self):
        """获取可用摄像头列表"""
        camera_list = []
        for i in range(4):
            cap = cv2.VideoCapture(i)
            if cap.isOpened():
                camera_list.append(f"Camera {i}")
                cap.release()
        return camera_list

    def start_camera(self):
        """启动摄像头并开始处理视频流"""
        if self.running:
            self.running = False
            self.cap.release()

        camera_index = int(self.camera_var.get().split()[1])
        self.cap = cv2.VideoCapture(camera_index)  # 选择的摄像头
        if not self.cap.isOpened():
            messagebox.showerror("Error", "Cannot open camera")
            return
        self.running = True
        self.process_camera()

    def stop_camera(self):
        """停止摄像头"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        self.screen.fill((0, 0, 0))  # 清空Pygame屏幕
        pygame.display.flip()

    def process_camera(self):
        """处理摄像头视频流"""
        if self.running:
            ret, frame = self.cap.read()
            if ret:
                self.process_frame(frame)
                self.root.after(10, self.process_camera)  # 每10毫秒处理一帧
            else:
                messagebox.showerror("Error", "Cannot read frame")
                self.running = False

    def upload_image(self):
        #上传并处理图片
        file_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg;*.jpeg;*.png")])
        if file_path:
            frame = cv2.imread(file_path)
            frame = self.resize_image(frame, self.frame_video.winfo_width(), self.frame_video.winfo_height())
            self.process_frame(frame, file_path)

    def upload_video(self):
        #上传并处理视频
        file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4;*.avi;*.mov")])
        if file_path:
            cap = cv2.VideoCapture(file_path)
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                self.process_frame(frame, file_path)
            cap.release()

    def resize_image(self, frame, max_width, max_height):
        #调整图像大小以适应指定的最大宽度和高度
        h, w = frame.shape[:2]
        scale = min(max_width / w, max_height / h)
        return cv2.resize(frame, (int(w * scale), int(h * scale)))

    def process_frame(self, frame, file_path=None):
        #处理视频帧并进行目标检测
        results = model(frame)
        smoking_conf = 0
        for result in results:
            for box in result.boxes:
                coords = box.xyxy.tolist()
                if len(coords) == 1 and len(coords[0]) == 4:
                    x1, y1, x2, y2 = coords[0]
                    conf = box.conf.item()
                    cls = box.cls.item()
                    label = f'{model.names[int(cls)]} {conf:.2f}'
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

                    # 检查检测到的类别是smocking并更新置信度
                    if model.names[int(cls)] == "smoking":
                        smoking_conf = max(smoking_conf, conf)
                        self.treeview.insert("", 0, values=(file_path or "Camera", f"({x1}, {y1}), ({x2}, {y2})", f"{conf:.2f}"))
                        if smoking_conf >= 0.7 and not pygame.mixer.music.get_busy():
                            self.play_alert_sound()
        

        # 将帧从BGR转换为RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # 将帧转换为Pygame图像
        frame = pygame.surfarray.make_surface(frame.swapaxes(0, 1))

        # 如果尚未创建Pygame窗口，则创建窗口
        if self.screen is None:
            os.environ['SDL_WINDOWID'] = str(self.frame_video.winfo_id())
            os.environ['SDL_VIDEODRIVER'] = 'windib'
            self.screen = pygame.display.set_mode((self.frame_video.winfo_width(), self.frame_video.winfo_height()))

        # 显示帧
        self.screen.blit(frame, (0, 0))
        pygame.display.flip()

    def play_alert_sound(self):
        """播放警报声音"""
        alert_sound_path = 'smock.mp3'
        if os.path.exists(alert_sound_path):
            pygame.mixer.music.load(alert_sound_path)
            pygame.mixer.music.play()

    def on_close(self):
        """关闭窗口时执行的操作"""
        self.running = False
        if hasattr(self, 'cap') and self.cap.isOpened():
            self.cap.release()
        pygame.quit()
        self.root.destroy()

if __name__ == "__main__":
    root = tk.Tk()
    app = FireDetectionApp(root)
    root.protocol("WM_DELETE_WINDOW", app.on_close)
    root.mainloop()
